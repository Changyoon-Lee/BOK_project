# %%
import pandas as pd

df = pd.read_csv('채권전처리용.csv')

df_Daesin = df[df['증권사'] == '대신증권']
df_Kafe = df[df['증권사'] == '케이프투자증권']
df_DB = df[df['증권사'] == 'DB금융투자']
df_E_trade = df[df['증권사'] == '이트레이드증권']
df_Mirae = df[df['증권사'] == '미래에셋대우']
df_LIG = df[df['증권사'] == 'LIG투자증권']
df_IBK = df[df['증권사'] == 'IBK투자증권']
df_Hana = df[df['증권사'] == '하나금융투자']
df_Kiwoom = df[df['증권사'] ==  '키움증권']
df_KTB = df[df['증권사'] == 'KTB투자증권']
df_Meritz = df[df['증권사'] == '메리츠종금증권']
df_Hanhwa = df[df['증권사'] == '한화투자증권']
df_HanaDT = df[df['증권사'] == '하나대투증권']
df_Kyobo = df[df['증권사'] == '교보증권']
df_E_best = df[df['증권사'] == '이베스트증권']
df_Hyundae = df[df['증권사'] == '현대차증권']
df_E_bestT = df[df['증권사'] == '이베스트투자증권']

# %% [markdown]
# # 대신증권

# %%
daesin_list = list(df_Daesin['내용'])

# %%
import re

# %%
D = []
for text in daesin_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('표', '', text)
    processing = re.sub('자료', '', processing)
    processing = re.sub('대신경제연구소', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('문남중', '', processing)
    processing = re.sub('김영일', '', processing)
    processing = re.sub('김훈길', '', processing)
    processing = re.sub('글로벌 채권형 펀드 플로우', '', processing)    
    processing = re.sub('선진국 순유입 전환', '', processing)   
    processing = re.sub('신흥국 순유출 지속', '', processing)   
    processing = re.sub('글로벌 주식형 펀드 플로우', '', processing)    
    processing = re.sub('선진국 순유출 전환', '', processing)    
    processing = re.sub('신흥국 순유출 지속', '', processing)    
    processing = re.sub('글로벌 플로우', '', processing)    
    processing = re.sub('선진국 순유출 전환', '', processing)   
    processing = re.sub('신흥국 순유출 지속', '', processing)
    processing = re.sub('선진국 및 신흥국', '', processing)
    processing = re.sub('자산 순유입 지속', '', processing)
    processing = re.sub('자산 순유입 전환', '', processing)
     
    
    
#     processing = re.sub('글로벌 채권형 펀드 플로우 선진국 순유입 지속 신흥국 순유출 지속 글로벌 주식형 펀드 플로우 선진국 및 신흥국 동반 순유입 전환 글로벌 플로우 선진국 순유입 지속 신흥국 순유입 전환', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    D.append(processed)

len(D)
# Out:
# 37

# %%
df_Daesin['내용'] = D
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
D[10]
# Out:
# ['월 주 글로벌 채권    월 주차 글로벌 채권형 펀드의 순유입 규모는 로 북미지역의 자산 유입세 전환으로 한주만에 자산 유입세로 전환되었다',
#  '전주까지만 해도 미 경제지 개선을 바탕으로 안전자산보다는 위험자산을 선호하는 성향이 높아지는 듯 했지만 그렉시트 우려감이 높아지고 국제유가 기준가 배럴당 달러를 하회하는 등 급락세가 이어짐에 따라 전반적으로 안전자산을 선호하는 성향이 급격이 높아지며 채권형펀드로 자금이 유입되는 모습이다',
#  '최근들어 유출입의 변동성이 높아지고 있는 북미지역은 금주들어 자금이 다시 유입되는 모습으로 안전자산 선호로 달러시 채권에 대한 수요가 높아진데 기인하며 서유럽 역시 그리스발 우려감이 채권선호를 높임에 따라 서유럽지역의 자금유입으로 연결된 상황이다',
#  '또한 신흥국의 자금유출은 주째 지속되는 모습으로 러시아 불안속 국제유가 하락이 신흥국 경제불안 우려를 높임에 따라 신흥국에 대한 심리가 위축되고 있는 모습이고 하이일드펀드는 전주에 이어 미 금리인상 경계감에 유출세가 지속되는 모습이다',
#  '글로벌 주간 자산 이동 지역별',
#  '글로벌 주간 자산 이동 별',
#  '권역별 주간 펀드 플로우',
#  '지역별 및 우 뗼',
#  '선진국 펀드 주간 플로우',
#  '이머징 펀드 주간 플로우',
#  '선진국 펀드 별 주간 변동',
#  '이머징 펀드 별 주간 변동 우 우     월 주 글로벌 주식 자산 순유출 전환   월 주차 글로벌 주식형 펀드의 순유출 규모는 로 한주만에 유출세가 급격히 확대되면서 위험자산을 선호하는 성향이 급감하는 모습이다',
#  '최근 주동안 유입세를 보였던 북미역은 전주 유입규모가 크게 줄며 위험선호 성향이 낮아졌던 상황으로 금주들어 유출세로 돌아섬에 따라 지난해 월 중순이후 급등했던 지수에 대한 부담감 및 그렉시트 재부각을 계기로 차익실현을 보인 것으로 보인다',
# ...

# %%
df_Daesin['내용']
# Out:
# 947     [유출로 돌아선 주식형  선진국 순유출 감소 신흥국 순유출 감소  선진국 순유입 감...
# 957     [업종 선호도는 상대성과, 점수주도력이익유동성기술적분석 주간 업종 선호도 선호업종 ...
# 958     [채권선호를 낮추는   신흥국 순유출 증가  선진국 순유입 증가 신흥국 순유출 증가...
# 1022    [유출세가 완화된 두 자산 가, 선진국 순유출 감소 신흥국 순유출 감소 나, 선진국...
# 1183    [안도감속 높아지는 위험선호 가, 선진국 순유출 증가 신흥국 순유출 감소 나, 선진...
# 1217    [월 주 글로벌 채권    월 주차 글로벌 채권형 펀드의 순유입 규모는 로 주째 자...
# 1230    [월 펀드시장 전망 자산전략실, 유동성을 끌어들일 가지성장 정책 개혁, 지난 월 글...
# 1236    [선진국 순유입 지속    동반 순유입 전환  선진국 순유입 지속 신흥국 순유입 전...
# 1242    [선진국 순유입 지속      선진국 순유입 지속, 월 주 글로벌 채권  선진국 순...
# 1245    [선진국 순유입 지속, 월 주 글로벌 채권  선진국 순유입 지속  월 주차 글로벌 ...
# 1255    [월 주 글로벌 채권    월 주차 글로벌 채권형 펀드의 순유입 규모는 로 북미지역...
# 1261    [선진국 순유입 지속   선진국 순유입 지속 신흥국 순유출 전환, 월 주 글로벌 채...
# 1267    [선진국 순유입 증가 신흥국 순유입 전환, 월 주 글로벌 채권    월 주차 글로벌...
# 1269    [동반 순유출 지속   자산 순유출 확대  선진국 순유입 감소 신흥국 순유출 증가,...
# 1274    [동반 순유출 전환     선진국 순유입 감소, 월 주 글로벌 채권 자산 순유출 전...
# 1278    [선진국 순유입 감소 신흥국 순유입 전환  선진국 순유입 감소 신흥국 순유출 전환 ...
# ...

# %% [markdown]
# #  케이프 투자 증권

# %%
df_Kafe = df[df['증권사'] == '케이프투자증권']

# %%
df_Kafe['내용']
# Out:
# 193     \n\n \n\n \n\nCAPE Research Division  ▶▶▶ \n\...
# 238    | 2017 년 06월 | \n\n2017년 채권시장 전망과 투자 아이디어 \n\n...
# 257     \n\n \n\n \n\nCAPE Research Division  ▶▶▶ \n\...
# 265     \n\n \n\n \n\n \n\n \n\n \n\nCAPE Research Di...
# 305     \n\n \n\n \n\nCAPE Research Division  ▶▶▶ \n\...
# 317           \n \n2017/03/24 \n \n \n\nCAPE \nFixed ...
# 322           \n \n2017/03/17 \n \n \n\nCAPE \nFixed ...
# 341     \n\n \n\n \n\n \n\nCAPE Research Division  ▶▶...
# 351           \n \n2017/02/10 \n \n \n\nCAPE \nFixed ...
# 379     \n\n \n\n \n\n \n\nCAPE Research Division  ▶▶...
# 380           \n \n2017/01/13 \n \n \n\nCAPE \nFixed ...
# 384           \n \n2017/01/06 \n \n \n\nCAPE \nFixed ...
# 391    | 2016년 11 |\n\n[채권시장 전망]\n[채권시장 전망]\n16.4Q~20...
# Name: 내용, dtype: object

# %%
Kafe_report = list(df_Kafe['내용'])

# %%
K_ = []
for text in Kafe_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    K_.append(text)

# %%
len(K_)
# Out:
# 13

# %%
K_[0]
# Out:
# '최운선. 월에도 동결국면 유지될 전망 한국은행은 국내경제가 견실한 성장세를 나타낼 것으로 예상하고 있으나 수요측면에서 물가상승압력이 크지 않을 것으로 전망하고 있음을 밝혔다. 즉 수요측면의 물가상승 압력이 가시화 되지 않는다면 금리인상으로 선회할 가능성이 낮음을 의미한다. 한편 가계부채와 부동산 가격 상승에 향후 민감하게 대응할 가능성을 보였다. 즉 가계부채 증가 억제 정책에도 불구하고 서울을 축으로 한 주택가격 상승이 물가상승률을 크게 상회할 경우 금리인상으로 정책방향을 전환할 수 있을 것으로 판단된다. 따라서 하반기 물가의 경우 보다 주택가격 상승 폭과 지속성에 대한 점점이 요구된다. 주택가격 상승과 실업률 하락이 중첩될 경우 기준금리 인상에 나설 것으로 보기 때문이다. 기준금리 결정 개월 연속 유지 한은은 세계경제의 회복세가 확대되고 있으나 국내 소비 증가세가 여전히 미흡하다는 인식을 보임. 그러나 수출과 투자가 개선되면서 견실한 성장세를 이어갈 것으로 기대함. 이와 같은 성장에도 불구하고 인플레이션 압력은 크지 않을 것으로 전망함. 이를 기반으로 기준금리 동결을 통해 통화정책 완화기조를 유지하면서 물가 상승률이 목표수준에서 안정될 수 있도록 정책을 운용해 나갈 것임을 밝힘 한은의 경기인식 세계경제 회복세 확대에 따른 수출과 투자 개선. 반면 소비는 여전히 미흡 글로벌 주요국의 경제 회복을 반영해 수출 확대 기조가 이어지고 이에 따른 설비투자 개선이 유지될 것으로 예상함 국내경제의 소비 증가세는 수출확대에도 불구하고 기대보다 낮은 수준의 회복을 보이고 있는 것으로 평가함. 그러나 주가상승과 부동산 가치 상승에 따른 소비심리 개선이 완만한 성장세를 지지해 줄 것으로 기대함 수출확대와 소비심리 개선이 소비확대로 이어질 경우 월 전망치인 성장률 를 상회할 것으로 기대함 물가는 상승압력이 높지 않을 것으로 전망함. 국제유가의 상승이 기대보다 가시화 되지 못하고 있어 수입물가 안정이 안정에 기여할 것으로 보기 때문인 것으로 판단됨. 반면 자산인플레이션 측면에
# ...

# %%
len(Kafe_report)
# Out:
# 13

# %%
K = []
for text in Kafe_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('표' , '', text)
    processing = re.sub('본 조사자료는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에도 무단 복제 및 배포 될 수 없습니다. 또한 본 자료에 수록된 내용은 당사가 신뢰할 만한 자료 및 정보로 얻어진 것이나 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 어떠한 경우에도 본 자료는 고객의 주식투자의 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다', '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('케이프투자증권', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('리서치센터', '', processing)
    processing = re.sub('최운선', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    K.append(processed)

len(K)
# Out:
# 13

# %%
K[9]
# Out:
# ['상반기 중 기준금리 인상 가능성은 낮아짐 한은의 시각이 크게 달라지지 않았다',
#  '년 국내 경제성장률 전망을 이전 대비 하향한 로 낮추었지만 대외불확실성으로 미 연준의 통화정책 정상화 추이 가계부채 증가세의 둔화 여부를 확인하고자 하는 의지를 피력했다',
#  '인플레이션에 있어 수입물가 상승이란 공급측면의 인플레이션이 물가를 끌어 올리고 수요측면의 물가상승 요인이 부가될 경우 대의 목물가 수준에 수렴할 것으로 예상했다',
#  '그러나 수요측면의 물가 상승 여부는 확인이 요구된다',
#  '이는 한은의 금리정책이 경기하방 위험이 부각되지 않는다면 현재의 입장이 유지될 것임을 의미한다',
#  '기준금리 결정 개월 연속 유지 중기적 시계에서 물가상승률이 목수준인 에 접근하도록 하면서 금융안정에 유의하여 통화정책을 운용한다는 기존의 입장을 유지했음',
#  '또한 통화정책에 영향을 줄 변수로서 미 연준의 통화정책 정상화 추이 미국 신정부의 재정확대 정책의 실행과 이에 따른 영향을 주목하고 있으며 국내요인으로 가계부채 증가세 여부를 점검하는 기존의 입장을 견지했음 한은의 경기인식 년 성장률 전망치 하향함',
#  '기존 월 전망 년 내수소비에 대한 기대치를 하향',
#  '기존 민간소비가 성장할 것이란 전망에서 하향한 로 예상함 그러나 설비투자는 기존 에서 로 상향했으며 건설투자도 에서 로 상향함 수출과 수입의 경우 기존대비 수출은 하향한 로 수입은 상승한 로 전망했음 물가의 경우 연간 로 이전 대비 하향했으며 이는 하반기 수입물가 상승 영향이 상반기 대비 낮아질 것을 고려한 것으로 판단됨 통화정책 전망 상반기 물가 상승 압력을 제외하고 실물부문의 성장에 의한 금리인상 가능성은 낮아짐 민간소비 둔화는 수입물가 상승이 주는 구매력 감소 대출이자의 부담이 상승하는 가운데 부동산 경기 정체에 의한 자산효과 약화를 고려한 것으로 판단됨',
#  '주목할 점은 설비투자가 기저효과를 반영하며 증가할 것으로 본 것임',
# ...

# %%
df_Kafe['내용'] = K
df_Kafe['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 193    [월에도 동결국면 유지될 전망 한국은행은 국내경제가 견실한 성장세를 나타낼 것으로 ...
# 238    [년 월 년 채권시장 전망과 투자 아이디어 년 월 텐트럼 소프트 패치, 년 채권시장...
# 257    [추경 효과를 기다리는 관망정책 유지할 전망 한국은행의 통화정책 방향은 크게 변한 ...
# 265    [채권크레딧 국가채무 비중 허들 문재인 정부 출범 후 채권시장은 경기확장이란 변수 ...
# 305    [연내 기준금리 동결 가능성 한국은행의 연내 기준금리 동결 가능성이 높아졌다, 향후...
# 317    [월말 지호전 부담되나 필립스 커브 평탄화를 주목 국내 채권시장 리뷰 급락한 단기물...
# 322    [박스권 재진입 후 세제 개혁안을 기다리는 관망 국내 채권시장 리뷰 미국 정책금리 ...
# 341    [월에도 기준금리 동결기조는 이어질 전망 한국은행의 금리정책에 대한 입장은 월 대비...
# 351    [트럼프 정책에 대한 저항이 투자심리에 긍정적 국내 채권시장 리뷰 트럼프 행정부의 ...
# ...

# %%
DB_list = list(df_DB['내용'])

# %%
len(DB_list)
# Out:
# 1

# %%
DB_list
# Out:
# ['글로벌  자산배분 \n\n \n\n \n\n \n\n \n\n2016. 07. 25 \n \n\nAUGUST \n\n정책  당국자의 일부 변심  →  차익실현의 명분 \n\n브렉시트  충격파에서  빠르게 벗어나면서  글로벌 자산시장이  랠리를 펼쳤다. 글로벌  정책공조 \n기대감이  배경이다.  8월에는  경기부양책에  대한  높은  기대감을  정책당국이  맞춰줄  수  있는지     \n여부가  시장 방향성을 결정할 것이다. 헬리콥터 머니까지  제시되는 상상력이  동원된 경기부양\n책을  정책당국이  100%  수용하기는 어렵다고  본다.  정부는 컨틴전시  플랜을  준비했는데, 컨틴\n전시  상황이 발생하지  않아서 플랜을 공격적으로  가동할  필요가  없기  때문이다. 여지는 남겨두\n겠지만  일부  정책당국자는  이전에 말했던  강력한  정책들을  살며시  거둬들일  것이다.  이는  투자\n자들이  눈높이를  낮추면서  가격이 급등한  자산의  차익실현  명분으로  활용될 전망이다. \n\n8월에는  공격보다는 수비가 필요한 시점이라고 판단한다. 따라서  차익실현에 노출될  가능성이 \n높은  자산군에 대해서는 비중을  축소할  필요가 있다. 일단 주식자산군이  여기에 속한다. 주식\n자산군을  제외할  경우엔  자산군내에서  밸류에이션에  기반해  투자할  자산을  엄중하게 선정할 \n필요가  있다. 포지션의  쏠림  현상  역시 의사결정에  반영해야  한다.  채권자산은  금리가  상승할 \n때마다  필요한  채권을  매입하자.  원자재는  메이저품목보다는  수급이  타이트한  마이너품목에 \n관심을  가져야  한다.  \n\n \n\nGlobal Asset + α Portfolio\n\n국내 주식\n\n13.0%\n\n국내주식\n\nCore\n\n76.1%\n\n해외주식\n\n21.0%\n\n국내채권\n\n31.7%\n\n해외채권\n\n대체투자\n\n3.4%\n\n7.0%\n\n원자재\n\n미국\n\n유럽\n\n일본\n\n신흥국\n\n회사
# ...

# %%
DB_ = []
for text in DB_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    DB_.append(text)

DB_[0]
# Out:
# '글로벌 자산배분 . . 정책 당국자의 일부 변심 차익실현의 명분 브렉시트 충격파에서 빠르게 벗어나면서 글로벌 자산시장이 랠리를 펼쳤다. 글로벌 정책공조 기대감이 배경이다. 월에는 경기부양책에 대한 높은 기대감을 정책당국이 맞춰줄 수 있는지 여부가 시장 방향성을 결정할 것이다. 헬리콥터 머니까지 제시되는 상상력이 동원된 경기부양책을 정책당국이 수용하기는 어렵다고 본다. 정부는 컨틴전시 플랜을 준비했는데 컨틴전시 상황이 발생하지 않아서 플랜을 공격적으로 가동할 필요가 없기 때문이다. 여지는 남겨두겠지만 일부 정책당국자는 이전에 말했던 강력한 정책들을 살며시 거둬들일 것이다. 이는 투자자들이 눈높이를 낮추면서 가격이 급등한 자산의 차익실현 명분으로 활용될 전망이다. 월에는 공격보다는 수비가 필요한 시점이라고 판단한다. 따라서 차익실현에 노출될 가능성이 높은 자산군에 대해서는 비중을 축소할 필요가 있다. 일단 주식자산군이 여기에 속한다. 주식자산군을 제외할 경우엔 자산군내에서 밸류에이션에 기반해 투자할 자산을 엄중하게 선정할 필요가 있다. 포지션의 쏠림 현상 역시 의사결정에 반영해야 한다. 채권자산은 금리가 상승할 때마다 필요한 채권을 매입하자. 원자재는 메이저품목보다는 수급이 타이트한 마이너품목에 관심을 가져야 한다. 국내 주식국내주식해외주식국내채권해외채권대체투자원자재미국유럽일본신흥국회사채국고채단기채미국채유동성현금주식전략팀채권전략팀 경제자산전략 장화탁 신용분석 박정호 신용분석 유승우 채권전략 문홍철 해외주식원자재 유경하 국내주식시황 강현기 해외채권 박유나 퀀트 남기윤 대체투자 정승기 퀀트 설태현 신용분석 이훈호 자산분석 권아민 최혁재 주식전략팀채권전략팀 .. 월 . . 높아진 기대감을 정책당국자가 맞추기는 쉽지 않은 상황 지금 자산시장을 움직이는 드라이브 팩터는 정책이다. 월에 발표되는 정책이 높아진 시장 기대치를 충족할 것인지를 판단하는 것이 중요하다. 브렉시트 이후 예상된 정책들은 컨틴전시 플랜이었다. 금융시장의 빠른 안정으로 예외적인 정책을 긴급히 사용할
# ...

# %%
DB = []
for text in DB_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    
    processing = re.sub('표', '', text)
    processing = re.sub('자료', '', processing)
    processing = re.sub('그림', '', processing)

    processing = re.sub('본 조사는 당사의 허락없이 무단 복제 및 배포할 수 없습니다', '', processing)
    processing = re.sub('동 내용은 기관투자자 등에게 지난 개월간 을 통해 사전 제공된 바 없습니다', '', processing)
    processing = re.sub('이 에 게재된 내용들은 본인의 의견을 정확하게 반영하고 있으며 외부의 부당한 압력이나 간섭없이 작성되었음을 확인합니다', '', processing)
    processing = re.sub('본 조사는 고객의 투자참고용으로 작성된 것이며 당사의 리서치센터가 신뢰할 수 있는  및 정보로부터 얻어진 것이나 당사가 그 정확성이나 완전성을 보장할 수 없으므로 어떠한 경우에도 고객의 증권투자결과에 대한 법적 책임소재의 증빙로 사용될 수 없습니다', '', processing)
    processing = re.sub('당사는  발간일 현재 조사분석에 언급된 법인과 독점규제 및 공정거래에 관한 법률 제조 제호에 따른 계열회사의 관계에 있지 않습니다', '', processing)
    processing = re.sub('당사는  발간일 현재 위 조사분석에 언급된 종목의 지분을 이상 보유하고 있지 않습니다', '', processing)
    processing = re.sub('당사는  발간일 현재 지난 년간 위 조사분석에 언급한 종목들의 대주관업무를 수행한 사실이 없습니다', '', processing)
    processing = re.sub('발간일 현재 본 를 작성한 조사분석담당자는 해당종목과 재산적 이해관계가 없습니다', '', processing)
    processing = re.sub('팀 명 리서치센터 주식전략팀 담 당 리서치센터장 글로벌자산배분 해외주식원자재 국내주식시황 채권전략팀 기업분석 팀 은행보험 퀀트 대체투자 퀀트 자산분석 신용분석 신용분석 채권전략 해외채권 신용분석 코디네이터 음식료유통 제약바이오 운송 자동차 화장품의류 조선기계 건설지주 통신미디어 화학정유유틸리티에너지 한승재 기업분석 팀 총괄 엔터레저인터넷게임 권윤구 용대인 장화탁 유경하 강현기 남기윤 정승기 설태현 권아민 박정호 유승우 문홍철 박유나 이훈호 최혁재 박세미 이병건 차재헌 구자용 노상원 김평모 박현진 신은정 윤나라 권성률 김홍균 조윤호 박상하 상무 팀장 수석연구원 수석연구원 선임연구원 선임연구원 선임연구원 연구원 팀장 수석연구위원 연구위원 수석연구원 선임연구원 연구원 사원 팀장 수석연구위원 연구위원 수석연구원 수석연구원 선임연구원 선임연구원 연구원 사원 팀장 수석연구위원 연구위원 선임연구원 선임연구원 주식전략팀채권전략팀', '', processing)
     
    
    
#     processing = re.sub('글로벌 채권형 펀드 플로우 선진국 순유입 지속 신흥국 순유출 지속 글로벌 주식형 펀드 플로우 선진국 및 신흥국 동반 순유입 전환 글로벌 플로우 선진국 순유입 지속 신흥국 순유입 전환', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    DB.append(processed)

len(DB)
# Out:
# 1

# %%
DB[0]
# Out:
# ['글로벌 자산배분',
#  '정책 당국자의 일부 변심 차익실현의 명분 브렉시트 충격파에서 빠르게 벗어나면서 글로벌 자산시장이 랠리를 펼쳤다',
#  '글로벌 정책공조 기대감이 배경이다',
#  '월에는 경기부양책에 대한 높은 기대감을 정책당국이 맞춰줄 수 있는지 여부가 시장 방향성을 결정할 것이다',
#  '헬리콥터 머니까지 제시되는 상상력이 동원된 경기부양책을 정책당국이 수용하기는 어렵다고 본다',
#  '정부는 컨틴전시 플랜을 준비했는데 컨틴전시 상황이 발생하지 않아서 플랜을 공격적으로 가동할 필요가 없기 때문이다',
#  '여지는 남겨두겠지만 일부 정책당국자는 이전에 말했던 강력한 정책들을 살며시 거둬들일 것이다',
#  '이는 투자자들이 눈높이를 낮추면서 가격이 급등한 자산의 차익실현 명분으로 활용될 전망이다',
#  '월에는 공격보다는 수비가 필요한 시점이라고 판단한다',
#  '따라서 차익실현에 노출될 가능성이 높은 자산군에 대해서는 비중을 축소할 필요가 있다',
#  '일단 주식자산군이 여기에 속한다',
#  '주식자산군을 제외할 경우엔 자산군내에서 밸류에이션에 기반해 투자할 자산을 엄중하게 선정할 필요가 있다',
#  '포지션의 쏠림 현상 역시 의사결정에 반영해야 한다',
#  '채권자산은 금리가 상승할 때마다 필요한 채권을 매입하자',
#  '원자재는 메이저품목보다는 수급이 타이트한 마이너품목에 관심을 가져야 한다',
#  '국내 주식국내주식해외주식국내채권해외채권대체투자원자재미국유럽일본신흥국회사채국고채단기채미국채유동성현금주식전략팀채권전략팀 경제자산전략 장화탁 신용분석 박정호 신용분석 유승우 채권전략 문홍철 해외주식원자재 유경하 국내주식시황 강현기 해외채권 박유나 퀀트 남기윤 대체투자 정승기 퀀트 설태현 신용분석 이훈호 자산분석 권아민 최혁재 주식전략팀채권전략팀',
#  '월',
#  '높아진 기대감을 정책당국자가 맞추기는 쉽지 않은 상황 지금 자산시장을 움직이는 드라이브 팩터는 정책이다',
# ...

# %%
df_DB['내용'] = DB
df_DB['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 512    [글로벌 자산배분, 정책 당국자의 일부 변심 차익실현의 명분 브렉시트 충격파에서 빠...
# Name: 내용, dtype: object

# %%
E_trade_list = list(df_E_trade['내용'])

# %%
E_trade_ = []
for et in E_trade_list:
    e = re.sub('[0-9](.)[0-9]', '', et)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', e)
    text = (' ').join(re.findall('[가-힣.]+', text))
    E_trade_.append(text)

# %%
E_trade_[0]
# Out:
# '집 팔아서 인도 채권 사라 크레딧크레딧크레딧크레딧 인도로 가야 안전합니다 손소현 .. 용을 이긴 코끼리 백한 사실이다. 끼리가 등장했다. 지난 월 일 인도 정부는 년 분기 성장률이 전년동기비 를 기록했다고 밝혔다. 회계연도 성장률 전망치는 에서 로 상향 조정했다. 성장률 상향 조정은 집계시 기준 연도를 회계연도에서 회계연도로 바꾼 것의 영향이 컸다. 하지만 기준 연도 변경을 차치하고서라도 인도 경제의 성장세는 명얼마 전 전인대에서 중국은 올해 성장률 목표치를 로 하향 조정했지만 주요 기관들의 인도 성장률은 속속 상향 조정되고 있다. 인도는 바야흐로 인구 억 이상 초대형국 가운데 가장 성장률이 높은 나라로 자리매김했다. 말 그대로 용을 이긴 코그림 기존의 산정방식으로도 인도는 중국을 추월 중국인도 자료 무디스 이 베스트투자증권 리서치본부 그렇다면 그 어떤 때보다 빠르게 달리고 있는 인도 코끼리에 올라탈 방법은 무엇인가. 지금 당장 인도 채권을 사라 인도 채권을 사는 것이다. 연내 기준금리 추가 인하 가능성 상존 올해 초 당사의 투자전략팀에서 인사동이라는 자료를 통해 올해 중국과 인도 인도네시아를 주목하라고 할 때만 해도 인도의 기준금리는 였다. 인도중앙은행 총재 라구잠 라잔이 년에 취임한 이후 두자릿수대를 넘나드는 인도의 소비자물가상승률을 잡기 위해 기준금리를 세 차례나 인상한 결과였다. 이 베스트투자증권 리서치본부 인도로 가야 안전합니다 하지만 인도의 소비자물가상승률은 적극적인 통화정책 및 유가 하락 등의 영향으로 안정적으로 하락세를 보였으며 년 월에는 까지 낮아졌다. 물가가 안정되면서 인플레이션 강경론자인 라잔 총재도 완화적 통화정책에 대한 기대에 부응해 올해 두 번이나 기준금리를 인하했다. 하지만 인도의 기준금리는 로 아직도 높은 수준이며 연내 기준금리 추가 인하 기대감 또한 여전히 상존한다. 인도는 글로벌 금융위기의 여파를 재정 완화책을 통해 극복하면서 재정적자를 기록하고 있으며 이로 인해 모디 정부는 재정정책 보다는 통화정책을 통해 경기를 부양할 
# ...

# %%
len(E_trade_list)
# Out:
# 49

# %%
E_trade = []
for et in E_trade_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('본 자료는 고객의 증권투자를 돕기 위한 정보제공을 목적으로 제작되었습니다. 본 자료에 수록된 내용은 당사 리서치본부가 신뢰할 만한 자료 및 정보를 바탕으로 작성한 것이나 당사가 그 정확성이나 완전성을 보장할 수 없으므로 참고자료로만 활용하시기 바라며 유가증권 투자 시 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 본 자료는 어떠한 경우에도 고객의 증권투자 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다. 본 자료는 당사의 저작물로서 모든 저작권은 당사에게 있으며 어떠한 경우에도 당사의 동의 없이 복제 배포 전송 변형될 수 없습니다. 동 자료는 제공시점 현재 기관투자가 또는 제자에게 사전 제공한 사실이 없습니다. 동 자료의 추천종목은 전일 기준 현재당사에서 이상 보유하고 있지 않습니다. 동 자료의 추천종목은 전일 기준 현재 당사의 조사분석 담당자 및 그 배우자 등 관련자가 보유하고 있지 않습니다. 동 자료의 추천종목에 해당하는 회사는 당사와 계열회사 관계에 있지 않습니다. 이 베스트투자증권 리서치본부', '', text)
    processing = re.sub('표', '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('권규백', '', processing)
    processing = re.sub('손소현', '', processing)
    
     
        
    
#     processing = re.sub('글로벌 채권형 펀드 플로우 선진국 순유입 지속 신흥국 순유출 지속 글로벌 주식형 펀드 플로우 선진국 및 신흥국 동반 순유입 전환 글로벌 플로우 선진국 순유입 지속 신흥국 순유입 전환', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    E_trade.append(processed)

len(E_trade)
# Out:
# 49

# %%
E_trade[10]
# Out:
# ['미국 에너지 기업 유가 급락 그 이후',
#  '크레딧 시장 동향 수요예측 회사채 발행시장 활기',
#  '월 중 국내 크레딧 스프레드는 예상치를 상회하는 축소폭을 나타냈다',
#  '일 기준 회사채 년물 크레딧 스프레드는 수준이다',
#  '말 그대로 무엇을 상상하든 그 이상을 보여주는 서프라이즈한 크레딧 스프레드이다',
#  '월 회사채 발행희망 금액은 억원 유효수요 금액은 억원으로 경쟁률은 에 달했다',
#  '크레딧물에 대한 풍부한 투자 수요로 전달 연말요인으로 주춤했던 회사채 수요예측 시장이 깨어났다',
#  '발행시장 회사채를 제외한 모든 섹터에서 발행 급감 크레딧물공사채 은행채 여전채 회사채은 조원 발행 조원 만기로 조원의 순상환을 기록했다',
#  '예보채 조원 등 대규모 공사채 만기가 도래하며 순상환 폭이 확대됐다',
#  '유통시장 크레딧 스프레드 큰 폭으로 축소 지난해말 확대됐던 크레딧 스프레드는 연초 자금집행 재개 및 크레딧물에 대한 높은 수요로 축소 전환됐다',
#  '전월 확대폭이 가장 컸던 여전채를 중심으로 되돌림 현상이 심했다',
#  '이슈 미국 에너지 기업 유가 급락 그 이후 유가 급락 이후 미국 에너지 기업들은 자본지출 삭감 프로젝트 연기 및 축소 등으로 재정건전성을 지키기 위해 노력중이다',
#  '의 미국 에너지 하이일드 인덱스는 지난 월 급락해',
#  '에서 저점을 형성한 후 소폭 반등해 현재는',
#  '이며 계속해서 등락을 거듭하며 불안정한 모습을 나타내고 있다',
#  '한편 미국내 전섹터를 포괄하는 하이일드 인덱스는 급락세 이후 꾸준히 우상향의 견조한 흐름을 보이며 안정을 되찾고 있다',
#  '이슈 산업별 차별화 지속 월중 업종별 크레딧 스프레드는 대부분 축소세를 보였으나 음식료품 제조업이 유일하게 확대되었다',
#  '전월 업황부진 등급하락 이슈로 스프레드 확대 폭이 컸던 운수업 및 기타운송장비 제조업의 스프레드는 보합 및 축소전환됐다 금융 시장 동향 회사채 년물 스프레드 국고채 년',
# ...

# %%
df_E_trade['내용'] = E_trade
df_E_trade['내용'][0]
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-c0edb8f9f478> in <module>
#       1 df_E_trade['내용'] = E_trade
# ----> 2 df_E_trade['내용'][0]
#
# ~\anaconda3\envs\nlp\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ...

# %%
Mirae_list = list(df_Mirae['내용'])

# %%
len(Mirae_list)
# Out:
# 73

# %%
Mr_ = []
for text in Mirae_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    Mr_.append(text)
    
Mr_[0]
# Out:
# '채권분석 채권 정의민 .. 사분기 통화정책 불확실성 확대 가능성 경계 월 회의 주요 내용 월 에서 한 차례 기준금리 인상을 결정하면서 년 연준은 총 세 차례 기준금리 인상을 단행. 다만 이는 미국 채권시장에 이미 선반영되었던 측면이 있음. 한편 월 성명서에서는 월 성명서 대비 특별한 문구 변화가 관측되지 않았음. 일단 월 에서 금융시장이 관심을 가진 부분은 크게 두 가지였을 것으로 판단됨. 트럼프 정부의 정책 영향 는 분기 경제전망에서 올해 성장률과 내년 성장률 전망치를 상향 조정했음년 년 . 이는 트럼프 정부의 세제 개혁 법안 효과를 상당 부분 반영했기 때문일 듯하나 년까지 코어 인플레 전망치 중간값은 월 대비 변화가 없었고 년 전망치 레인지 상하단은 약간 하락. 즉 의 인플레 전망에 근거하면 트럼프 정책 효과가 의 통화정책 속도에 미치는 영향은 제한적일 듯. 점도표 변화 월 대비 월 점도표는 큰 변화를 보이지 않았음. 점도표 중간값 기준으로 여전히 년 세 차례 기준금리 인상이 예상되고 있으며 년에는 두 차례 정도의 기준금리 인상이 예상되고 있음. 점도표 측면에서도 트럼프 정책 영향이 통화정책 경로 변화에 그리 큰 영향을 미치지 못할 것임을 추측할 수 있음. 실제로 옐런 의장은 기자회견에서 세제개편안 정책 효과를 이미 고려해서 통화정책 경로를 결정하고 있음을 밝힌 바 있음 . 사분기 통화정책 불확실성 확대 가능성 경계 통화정책 스탠스에 큰 변화가 관찰되지 않았으나 양호한 미국 경기 모멘텀을 고려하면 당장 분기 금리 인상 가능성이 적지 않다는 점은 부담. 또한 내년 연준 의장 뿐만 아니라 연준 이사지역 연은 총재 교체 이슈도 있기 때문에 사분기를 기준으로 통화정책 불확실성에 대한 우려가 일시적으로 높아질 수 있다는 점을 경계해야 할 듯. 월 기준금리 인상 확률 변화 좌 미국채 금리와 기준금리 인상 전망 변화 우 월 기준금리 인상 확률 좌미국채 년 금리 우자료 미래에셋대우 리서치센터 사분기 통화정책 불확실성 확대 가능성 경계 그림 . 년 월 점도표 자료 미
# ...

# %%
MR = []
for text in Mirae_list:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('당사는 본 자료를 제자에게 사전 제공한 사실이 없습니다. 본 자료는 외부의 부당한 압력이나 간섭없이 애널리스트의 의견이 정확하게 반영되었음을 확인합니다. 본 조사분석자료는 당사의 리서치센터가 신뢰할 수 있는 자료 및 정보로부터 얻은 것이나 당사가 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 종목 선택이나 투자시기에 대한 최종 결정을 하시기 바랍니다. 따라서 본 조사분석자료는 어떠한 경우에도 고객의 증권투자 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다. 본 조사분석자료의 지적재산권은 당사에 있으므로 당사의 허락 없이 무단 복제 및 배포할 수 없습니다.' , '', text)
    processing = re.sub('표', '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('미래에셋대우 리서치센터', '', processing)
    processing = re.sub('그림', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    MR.append(processed)

# %%
MR[0]
# Out:
# ['채권분석 채권 정의민',
#  '사분기 통화정책 불확실성 확대 가능성 경계 월 회의 주요 내용 월 에서 한 차례 기준금리 인상을 결정하면서 년 연준은 총 세 차례 기준금리 인상을 단행',
#  '다만 이는 미국 채권시장에 이미 선반영되었던 측면이 있음',
#  '한편 월 성명서에서는 월 성명서 대비 특별한 문구 변화가 관측되지 않았음',
#  '일단 월 에서 금융시장이 관심을 가진 부분은 크게 두 가지였을 것으로 판단됨',
#  '트럼프 정부의 정책 영향 는 분기 경제전망에서 올해 성장률과 내년 성장률 전망치를 상향 조정했음년 년',
#  '이는 트럼프 정부의 세제 개혁 법안 효과를 상당 부분 반영했기 때문일 듯하나 년까지 코어 인플레 전망치 중간값은 월 대비 변화가 없었고 년 전망치 레인지 상하단은 약간 하락',
#  '즉 의 인플레 전망에 근거하면 트럼프 정책 효과가 의 통화정책 속도에 미치는 영향은 제한적일 듯',
#  '점도 변화 월 대비 월 점도는 큰 변화를 보이지 않았음',
#  '점도 중간값 기준으로 여전히 년 세 차례 기준금리 인상이 예상되고 있으며 년에는 두 차례 정도의 기준금리 인상이 예상되고 있음',
#  '점도 측면에서도 트럼프 정책 영향이 통화정책 경로 변화에 그리 큰 영향을 미치지 못할 것임을 추측할 수 있음',
#  '실제로 옐런 의장은 기자회견에서 세제개편안 정책 효과를 이미 고려해서 통화정책 경로를 결정하고 있음을 밝힌 바 있음',
#  '사분기 통화정책 불확실성 확대 가능성 경계 통화정책 스탠스에 큰 변화가 관찰되지 않았으나 양호한 미국 경기 모멘텀을 고려하면 당장 분기 금리 인상 가능성이 적지 않다는 점은 부담',
#  '또한 내년 연준 의장 뿐만 아니라 연준 이사지역 연은 총재 교체 이슈도 있기 때문에 사분기를 기준으로 통화정책 불확실성에 대한 우려가 일시적으로 높아질 수 있다는 점을 경계해야 할 듯',
# ...

# %%
df_Mirae['내용'] = MR
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Mirae['내용']
# Out:
# 7      [채권분석 채권 정의민, 사분기 통화정책 불확실성 확대 가능성 경계 월 회의 주요 ...
# 12     [채권분석 채권 정의민, 년 트렌드 점검 한미 금리 역전 본격화 년 하반기 한미 기...
# 16     [은행채년여전년여전년, 수요예측금액유효수요유효경쟁률조원배, 수요예측금액유효수요유효경...
# 17     [채권분석 채권 정의민, 년 완만한 기준금리 인상 속도 예상 월 금통위 주요 내용 ...
# 27     [글로벌 채권시장 전망 정의민, 미래에셋대우 글로벌 채권 추천 자산전략미래에셋대우 ...
#                              ...
# 296    [미국을 중심으로 바닥 확인에 진입한 글로벌 금리 채권분석, 채권 윤여삼윤여삼윤여삼...
# 301    [크레딧 투자전략, 신용분석 이경록이경록이경록이경록, 안주영안주영안주영안주영, 두려...
# 302    [채권 윤여삼윤여삼윤여삼윤여삼, 김민형김민형김민형김민형, 월 금통위 신중한 낙관론 ...
# 303    [김민형김민형김민형김민형, 정의민정의민정의민정의민, 월 브라질 커진 자신감 기준금리...
# 311    [이슈 금리 인하 사이클 지속성 채권분석, 채권 정의민정의민정의민정의민, 김민형김민...
# Name: 내용, Length: 73, dtype: object

# %%
df_LIG = df[df['증권사'] == 'LIG투자증권']
LIG_report = list(df_LIG['내용'])

# %%
L_ = []
for text in LIG_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    L_.append(text)

# %%
len(L_)
# Out:
# 42

# %%
L_[10]
# Out:
# '최운선 . 월초 지표 호전을 경계하나 캐리의 기회로 활용 국내 채권시장 리뷰 김영란법 그리고 유가로 웃다 산업생산 호전으로 울었다 정책금리 동결 기존 로 동결. 시장이 주목한 것은 오는 월 인상 여부이며 현재 진행되는 미국 경기회복기조가 지속될 것인가에 대한 관심임. 월 대통령 선거를 앞두고 가 무리수를 둘 것으로 기대하기 어려우며 이는 향후 개월 동안 금리정책에 대한 불확실성이 대두되지 못할 것이란 기대를 제공함 미국의 원유재고 증가와 원유소비에 대한 부정적 시각 원유재고 증가가 소비감소에서 비롯된다는 지적과 더불어 하반기 유가상승에 대한 기대감이 크게 약화됨. 이는 하반기 유가를 비롯한 상품가격 상승이 수입물가 상승과 소비자물가상승을 이끌 것이란 기대를 약화시킴. 낮은 물가는 중앙은행의 정책변화를 자극하지 않으며 이는 캐리투자에 대한 명분을 제공함 월 산업활동 동향 호전과 투자심리 위축 월 산업활동이 투자와 소비를 중심으로 성장한 것에 대한 경계심리 부각됨. 자동차 및 가전제품의 경우 개별소비세 인하 종료를 반영하고 있으나 가격부담이 커진 채권시장에 부담으로 작용주간 채권시장 전망 전망 높은 가격부담과 실물지표 개선에 대한 부담이 박스권을 유도할 수 있으나 캐리투자 환경은 지속되고 있음 년물 . 년물 . 년물 . 해외경제 미국 분기 발표와 고용지표 그리고 제조업 지수가 관심을받을 전망. 지난 월 고용지표처럼 강력한 개선보다는 둔화가 예상되며 이는 시장에 안도를 줄 것으로 기대됨 국내경제 및 이슈 월 와 수출지표가 주목받을 전망. 가 시장이 기대하는 를 상회할 경우 시장에 부담. 특히 수출증가율의 마이너스 성장이 기대와 달리 축소될 경우 시장에 악재로 작용할 것임 투자전략 취약산업 구조조정 본격화 고려시 국내 산업활동 호전이 지속될지의문임. 미국의 고용지표 호전에 대한 불확실성은 선반영되었다는 인식으로 작용하며 주 후반 시장의 강세 모멘텀이 될 것으로 전망됨. 따라서 캐리투자에대한 포지션 유지와 크레딧물에 대한 투자확대 전략을 견지할 것을 권함. 특히 
# ...

# %%
L = []
for text in LIG_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('본 조사자료는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에도 무단 복제 및 배포 될 수 없습니다. 또한 본 자료에 수록된 내용은 당사가 신뢰할 만한 자료 및 정보로 얻어진 것이나 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 어떠한 경우에도 본 자료는 고객의 주식투자의 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다', '', text)
    processing = re.sub('표' , '', processing)    
    processing = re.sub('자료', '', processing)
    processing = re.sub('투자증권', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('리서치본부', '', processing)
    processing = re.sub('최운선', '', processing)
    processing = re.sub('유선웅', '', processing)
    processing = re.sub('문다솔', '', processing)
    processing = re.sub('김유겸', '', processing)
    processing = processing.split('.')
    
    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    L.append(processed)

# %%
df_LIG['내용'] = L
df_LIG['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 395    [트럼프가 행할 무역정책은 채권시장에 우호적 국내 채권시장 리뷰 환율 상승에도 외국...
# 404    [기준금리 동결 지속될 전망 년 분기에도 기준금리는 동결될 것으로 전망된다, 일 한...
# 421    [트럼플레이션 우려에서 투자기회를 찾을 때 국내 채권시장 리뷰 위기의식 지속과 매도...
# 433    [연말 트럼플레이션 반영은 달러인덱스 까지 국내 채권시장 리뷰 트럼프 당선으로 인플...
# 460    [가계부채 증가와 미국 금리인상 부담으로 기준금리 동결 월 미국 의 정책금리 인상이...
# 491    [동결원인은 가계대출 증가 부담과 미국 통화정책의 불확실성 금리결정에 가계부채의 증...
# 499    [가 올리면 는 내린다 국내 채권시장 리뷰 불안감 반영되며 투자심리 위축 외국인의 ...
# 522    [기다림이 필요한 때 국내 채권시장 리뷰 모멘텀 부재 속에서 미국발 리스크에 투자심...
# 525    [수출회복 지연 속에 추경마저 늦어지면 기준금리는 인하될 것 월 금통위에서 기준금리...
# ...

# %%
df_IBK = df[df['증권사'] == 'IBK투자증권']
df_IBK['내용']
IBK_report = list(df_IBK['내용'])

# %%
I_ = []
for text in IBK_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    I_.append(text)

# %%
len(I_)
# Out:
# 526

# %%
I_[0]
# Out:
# '. ......................................................................................................................................... 년 금리 완만한 상승 후 소폭 반락할 것으로 예상 ............................................................................... 대체 금리가 오르면 보험이 얼마나 좋아지는 걸까........................................................................................ . 년 금리 전망 ........................................................................................................................ . 년 변곡점을 거쳐 ....................................................................................................................................... . 내년 펀더멘털 기준금리 인상에 적합한가 ................................................................................................. . 기준금리 인상 년까지 총 회 예상 .................................................................................................... . 보험 분석에 앞서 ...................................................................................................
# ...

# %%
I = []
for text in IBK_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('본 조사자료는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에도 무단 복제 및 배포 될 수 없습니다. 또한 본 자료에 수록된 내용은 당사가 신뢰할 만한 자료 및 정보로 얻어진 것이나 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 어떠한 경우에도 본 자료는 고객의 주식투자의 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다', '', text)
    processing = re.sub('표' , '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('케이프투자증권', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('리서치센터', '', processing)
    processing = re.sub('최운선', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    I.append(processed)

# %%
df_IBK['내용'] = I
df_IBK['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 33      [년 금리 완만한 상승 후 소폭 반락할 것으로 예상, 대체 금리가 오르면 보험이 얼...
# 66      [월 월 인상 가능성 기정사실화 연준은 월 회의에서 기준금리를 만장일치 동결했다, ...
# 72      [과거 인상기와 지금을 비교해보면 금리를 움직이는 주된 요인이 통화정책에서 수급으로...
# 86      [인상 사이클의 시작 월 금통위 기준금리 동결했으나 인상 소수 의견이 개진되면서 시...
# 124     [미국 금리 하락의 원인 최근 미국 금리 하락이 두드러졌다, 월 이후부터 심화된 미...
#                               ...
# 2644    [미국 경제지 혼조 속 단기물과 장기물 금리의 등락이 엇갈림, 월 대신증권 무보증 ...
# 2646    [국내 채권시장 동향 채권 하락과 외국인 국채선물 대규모 순매수의 영향으로 금리하락...
# 2647    [국내 채권시장 동향 채권 저가매수세 유입으로 소폭 금리하락 마감, 억원 규모의 한...
# 2653    [채권분석 년 월 일 오창섭, 금리상승, 금리 부담 현재 금리수준에 대한 평가 현재...
# ...

# %%
df_Hana = df[df['증권사'] == '하나금융투자']
df_Hana['내용']
Hana_report = list(df_Hana['내용'])

# %%
H_ = []
for text in Hana_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))
    H_.append(text)

# %%
H_[0]
# Out:
# '년 월 일 트럼프노믹스를 극복한 년 시장 연간으로 본 년 성과는 나쁘지 않았다 대외변수 불확실성미국 신 행정부 출범에 대한 우려로 부정적 전망이 우세했던 년 크레딧채권시장이 기대이상의 선방을 하면서 마무리되고 있다. 년 크레딧시장의 무난한 성과는 글로벌자산시장의 호황에 기인하는 바가 크다. 주요국 주식시장은 사상최고치를 계속 갱신해나갔고 연준을 위시한 주요국 중앙은행들의 긴축적 통화정책에도 불구하고 시장금리는 하향안정세를 유지하면서 채권의 성과 또한 나쁘지 않았다. 특히 글로벌 하이일드채권 및 이머징 채권시장의 안정세는 국내 크레딧에도 긍정적인 영향을 끼치는데 일조하였다. 범 위험자산에 대한 수익추구현상이 가속화되는 가운데 신용채권만 소외될 일은 없었던 것이다. 김상만 . 김준태 .. 다만 년을 뒤로 하면서 년을 조망해보는 이 시점에서 나타나고 있는 현상은 앞으로의 시장흐름에 대해 다소 불편한 느낌을 주고 있다. 즉 연간단위 로 보면 신용스프레드가 하향안정 내지는 약보합세에 마무리되고 있지만 기중의 변동성이 크게 확대되었던 것이다. 특히 단기 은행채 스프레드의 등락은 초우량 신용채권의 위상에 걸맞지 않는 성격이었다. 유동성비율규제 등의 사유로 이 정도 흔들릴 가격이라면 만일 자본이슈 등 보다 본질적인 이슈가 제기된다면 어쩔 것인지. 본 조사자료는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에도 무단 복제 및 배포 될 수 없습니다. 또한 본 자료에 수록된 내용은 당사가 신뢰할 만한 자료 및 정보로 얻어진 것이나 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 어떠한 경우에도 본 자료는 고객의 주식투자의 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다. 년 수급적인 측면은 부담이 없을 것이다. 공사채여신금융채의 완만한 발 행 증가는 회사채은행채의 발행 감소로 상쇄될 것으로 보이기 때문이다. 수급은 늘 그래왔듯이 가격결정의 변수는 아니라는 점은 알고 있지만. 새해 복 많이
# ...

# %%
H = []
for text in Hana_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('본 조사자료는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에도 무단 복제 및 배포 될 수 없습니다. 또한 본 자료에 수록된 내용은 당사가 신뢰할 만한 자료 및 정보로 얻어진 것이나 그 정확성이나 완전성을 보장할 수 없으므로 투자자 자신의 판단과 책임하에 최종결정을 하시기 바랍니다. 따라서 어떠한 경우에도 본 자료는 고객의 주식투자의 결과에 대한 법적 책임소재의 증빙자료로 사용될 수 없습니다', '', text)
    processing = re.sub('표' , '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('하나금융투자', '', processing)
    processing = re.sub('그림', '', processing)
    processing = re.sub('인포맥스', '', processing)
    processing = re.sub('김상만', '', processing)
    processing = re.sub('이미선', '', processing)
    processing = re.sub('윤정수', '', processing)
    processing = re.sub('박승진', '', processing)
    processing = re.sub('이길영', '', processing)
    processing = re.sub('문이다', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    H.append(processed)

# %%
df_Hana['내용'] = H
df_Hana['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       [년 월 일 트럼프노믹스를 극복한 년 시장 연간으로 본 년 성과는 나쁘지 않았다 대...
# 2       [채권, 본 조사는 고객의 투자에 정보를 제공할 목적으로 작성되었으며 어떠한 경우에...
# 6       [채권, 년 월 일 월 함의와 년 연준구성 변화 처음으로 점도 약속을 지킨 연준, ...
# 9       [년 월 일 이제는 집에 가야 할 시간 해외발 자본규제관련 뉴스는 은행채에 긍정적으...
# 11      [년 월 일 브라질 기준금리 인하한 실직고 브라질 기준금리 인하년 월 일 기준 브라...
#                               ...
# 1074    [해외채권 해외채권, 브라질은 무디스가 에서 로 등급을 조정했던 년 월 이후 년만에...
# 1082    [년 월 일 이제부터는 다시 장기채다 기준금리 인하 기대 확산되며 국고년 금리 사상...
# 1084    [해외채권 해외채권, 있어 중앙은행은 운신의 폭이 좁아진 상황이다, 년 월 일 브라...
# 1085    [년 월 일 중국 채권펀드 추가 유출가능성 존재 선진국주식 주만에 순유입 전환, 신...
# ...

# %%
df_Kiwoom = df[df['증권사'] ==  '키움증권']
df_Kiwoom['내용']
Kiwoom_report = list(df_Kiwoom['내용'])

# %%
K_ = []
for Kiwoom in Kiwoom_report:
    ha = re.sub('[0-9](.)[0-9]', '', Kiwoom)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', ha)
    text = (' ').join(re.findall('[가-힣.]+', text))
    K_.append(text)

# %%
len(K_)
# Out:
# 176

# %%
K_[150]
# Out:
# '. . . 크레딧이슈 커버드본드 가계대출구조변경 위한 커버드본드 장기채 활성화를 기대하며 이화진 . 가계부채 문제와 정부대책의 핵심내용 커버드본드 활성화 통한 대출구조 변경 커버드본드 금리메리트와 활성화를 위한 제언 가계대출문제 대책 시의적절 파급효과는 작을 듯 크레딧이슈로 부각되고 있는 가계부채 문제에 대해 금융위는 지난 월 일 가계부채 연착륙 종합대책을 냈고 지난 월 일 은행에 세부 시행 사항을 은행에 통보했핵심은 가계부채 부실화 방지를 위해 무분별한 대출 경쟁을 막고 채무자의 상환능력 평가를 강화하며 고정금리 비거치분할상환 대출 비중을 확대해 안정적으로 원리금 상환이 가능하도록 한다는 것이다. 예대율 하향조정 적립금 및 확대 등 고강도 대책은 아직 결론부터 말하자면 예대율 비율 하향조정 가계부채 부실화에 따른 충당금 적립금 총부채상환비율 확대적용 등 고강도의 대책은 없었고 가장 핵심이 될 만한 것대출구조개선책 먼저 은 가계 부채 구조 개선을 위한 년 고정금리 비거치식 분할 상환 대출 비율현재 수준까지 확대 시행한다는 것이었다. 이는 대부분의 대출이 변동금리 거치식으로 이자만 내다 원금을 갚을 시점에서 다시거치기간을 연장해 이자만 갚아가는 형태로 대출 구조가 왜곡된 것을 바로 잡겠다는한국 가계대출문제 안심할 수 없어 상반기 주가 급증 기업실적 호조 등 경기회복세가 나타나면서 가계 부채 문제에 간다. 것이다. 과하기 쉬울 수 있으나 안심할 수 있는 수준은 아니다. 국내 가계 대출 증가세와 소득대비 대출 규모는 평균을 상회하는 수준이다. 또한 주택담보대출 연체율 년 말 한국 미국 수준으로 양호하지만 우리 나라 가계 대출은 만기가 짧고 변동금리 거치식으로 이자만 갚아가는 대출 비중이 크기 때문에 상대적으로 상환부담이 적다는 점을 감안해야 한다. 동 자료에 게시된 내용들은 본인의 의견을 정확하게 반영하고 있으며 외부의 부당한 압력이나 간섭 없이 작성되었음을 확인합니다 본 자료는 투자자의 증권투자를 돕기 위하여 당사 고객에 한하여 배포되는 자료로서 어떠한 경우
# ...

# %%
K = []
for text in Kiwoom_report:
    text = re.sub('[0-9](.)[0-9]', '', text)
    text = re.compile('[^ ㄱ-ㅣ가-힣.]+').sub('', text)
    text = (' ').join(re.findall('[가-힣.]+', text))

    processing = re.sub('본 자료는 투자자의 증권투자를 돕기 위하여 작성된 당사의 저작물입니다. 당사 고객에 한하여 배포되는 자료로서 어떠한 경우에도 복사 배포 전송 변형 대여될 수 없습니다. 본 조사자료에 수록된 내용은 당사 리서치센터가 신뢰할 만한 자료 및 정보로부터 얻어진 것이나 당사는 그 정확성이나 안전성을 보장할 수 없습니다. 따라서 어떠한 경우에도 본 자료는 고객의 증권투자의 결과에 대한 법적 책임소재에 대한 증빙자료로 사용할 수 없습니다.', '', text)

    processing = re.sub('표' , '', processing)
    processing = re.sub('자료', '', processing)
    processing = re.sub('그림', '', processing)

    processing = re.sub('키움증권', '', processing)
    processing = re.sub('키움', '', processing)
    processing = re.sub('이화진', '', processing)
    processing = re.sub('김세헌', '', processing)
    processing = re.sub('유재호', '', processing)
    processing = re.sub('이소원', '', processing)
    processing = re.sub('리서치', '', processing)
    processing = re.sub('안상우', '', processing)
    processing = re.sub('년 월 일 주간 동향과 스프레드 전망', '', processing)
    processing = processing.split('.')

    processed = []
    for pro in processing:
        pro = pro.strip()
        if pro:
            processed.append(pro)
    K.append(processed)
    
df_Kiwoom['내용'] = K
df_Kiwoom['내용']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 47      [채권시장은 미국 연준의장 인선 등 주요 이벤트가 마무리, 영란은행이 기준금리를 인...
# 55      [채권시장은 미국 월 금리 동결 제롬 파월 연준 이사의 연준의장 지명으로 예상밖의 ...
# 98      [채권시장은 일 미국 전략폭격기가 북방한계선을 넘어가면서 북한에 경고 메시지를 보냈...
# 118     [채권시장은 북한 건군절 추가 핵실험 우려로 지정학적 리스크가 재부각 됐고 미국 허...
# 130     [채권시장은 금통위 경계감과 단기물 중심의 매수세로 전반적인 보합세 속에서 커브 스...
#                               ...
# 2146    [크레딧이슈 국민카드 카드로 이관되는 채권의 스프레드 전망, 국민카드채로 변경 상장...
# 2149    [너무 낙관적인 물가전망 한은 수정 경제전망 년 년 성장률과 년 물가상승률을 상향 ...
# 2153    [전격적인 긴축 가능성 유동성 사정이 달라질 조짐 긴축개시 포르투갈 스페인 보다 물...
# 2158    [한국 월 외환보유고십억외환보유고 증감좌외환보유고 잔액우, 유로 월 좌 전월대비우 ...
# ...
